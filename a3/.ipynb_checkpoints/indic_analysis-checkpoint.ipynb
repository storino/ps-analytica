# %%
import basedosdados as bd
import numpy as np

# %%
df_br_ibge_pib_municipio = bd.read_table(dataset_id='br_ibge_pib',
table_id='municipio',
billing_project_id='45888281253')
df_br_ibge_pib_municipio.sample(5)
# Out:
# Downloading: 100%|██████████| 100186/100186 [00:22<00:00, 4492.30rows/s]
#         ano id_municipio          pib  impostos_liquidos           va  \
# 53659  2011      3529104     19854756             363984     19490772
# 97950  2019      3506003  15324591287         1454079579  13870511708
# 798    2002      2206670      8216470             165347      8051122
# 21965  2005      5107305    198020028           15400314    182619714
# 51595  2011      2605905    136235825            4381478    131854347
#
#        va_agropecuaria  va_industria  va_servicos  va_adespss
# 53659          5048508       1177579      5135822     8128863
# 97950         43609565    2400670239   9930604876  1495627028
# 798            1004634        230247      1435174     5381068
# 21965         88467011      26990460     43707904    23454339
# 51595         31720371       3472261     28738462    67923253

# %%
df_br_ibge_pib_municipio.corr()
# Out:
#                         ano       pib  impostos_liquidos        va  \
# ano                1.000000  0.040619           0.030014  0.042833
# pib                0.040619  1.000000           0.985064  0.999252
# impostos_liquidos  0.030014  0.985064           1.000000  0.977670
# va                 0.042833  0.999252           0.977670  1.000000
# va_agropecuaria    0.212074  0.072694           0.046636  0.078247
# va_industria       0.051872  0.860754           0.839931  0.861900
# va_servicos        0.033259  0.988647           0.974960  0.987665
# va_adespss         0.046929  0.758388           0.710462  0.766039
#
#                    va_agropecuaria  va_industria  va_servicos  va_adespss
# ano                       0.212074      0.051872     0.033259    0.046929
# pib                       0.072694      0.860754     0.988647    0.758388
# impostos_liquidos         0.046636      0.839931     0.974960    0.710462
# ...

# %%
df_adh_brasil = bd.read_table(dataset_id='mundo_onu_adh',
table_id='brasil',
billing_project_id='45888281253')
df_adh_brasil.sample()
# Out:
# Downloading: 100%|██████████| 3/3 [00:00<00:00,  8.46rows/s]
#     ano  expectativa_vida  fecundidade_total  mortalidade_1  mortalidade_5  \
# 0  1991             64.73               2.88          44.68          55.74
#
#    razao_dependencia  prob_sobrevivencia_40  prob_sobrevivencia_60  \
# 0              65.43                   86.9                  70.93
#
#    taxa_envelhecimento  expectativa_anos_estudo  ...  pia  pia_10_14  \
# 0                 4.83                     8.16  ...  NaN        NaN
#
#    pia_15_17  pia_18_mais  indice_escolaridade  indice_frequencia_escolar  \
# 0        NaN          NaN                0.301                      0.268
#
#     idhm  idhm_e  idhm_l  idhm_r
# 0  0.493   0.279   0.662   0.647
#
# [1 rows x 229 columns]

# %%
df_ips_rj = bd.read_table(dataset_id='br_rj_rio_de_janeiro_ipp_ips',
table_id='dimensoes_componentes',
billing_project_id='45888281253')
df_ips_rj.sample(5)
# Out:
# Downloading: 100%|██████████| 99/99 [00:00<00:00, 163.00rows/s]
#      ano regiao_administrativa  ips_geral  \
# 98  2020        Cidade De Deus      47.84
# 6   2016                 Lagoa      84.94
# 12  2016               Inhaúma      60.84
# 48  2018             Madureira      56.92
# 9   2016           Vila Isabel      74.12
#
#     necessidades_humanas_basicas_nota_dimensao  \
# 98                                       73.68
# 6                                        91.71
# 12                                       72.90
# 48                                       67.33
# 9                                        85.18
#
#     nutricao_cuidados_medicos_basicos  agua_saneamento  moradia  \
# 98                              55.73            93.43    65.41
# 6                               79.24            98.86    96.71
# 12                              70.68            92.05    82.90
# 48                              61.44            89.36    83.02
# ...

# %%
df_ips_rj.drop('ano', axis=1).corr()
# Out:
#                                             ips_geral  \
# ips_geral                                    1.000000
# necessidades_humanas_basicas_nota_dimensao   0.893947
# nutricao_cuidados_medicos_basicos            0.626019
# agua_saneamento                              0.278888
# moradia                                      0.755959
# seguranca_pessoal                            0.454276
# fundamentos_bem_estar_nota_dimensao          0.927117
# acesso_conhecimento_basico                   0.721696
# acesso_informacao                            0.941976
# saude_bem_estar                              0.449625
# qualidade_meio_ambiente                      0.567930
# oportunidades_nota_dimensao                  0.952439
# direitos_individuais                         0.116344
# liberdades_individuais                       0.790118
# tolerancia_inclusao                          0.847021
# acesso_educacao_superior                     0.953931
#
# ...

# %%
np.corrcoef([1,2,3], [4,5,1])
# Out:
# array([[ 1.        , -0.72057669],
#        [-0.72057669,  1.        ]])
